# %%
import os
#讀取位置
path = 'D:\\福壽_產學資料\\製粒機\\0901\\'
#存檔位置
save_path = 'D:\\福壽_產學資料\\製粒機_第一次處理\\0901\\'
#檔案檔名串列
file_list = os.listdir(path)
file_list

# %%
def cleanJsonData(file_list_before,file_list_after):
    with open(file_list_after,'w') as cleanData:
        with open(file_list_before,'r') as origin:
            countCry = 0
            jsonline = []
            for line in origin:
                if line =="\n":
                    countCry+=1
                    print("spacs line")
                else:
                    jsonline.append(line)

            print(jsonline)


            tmpCount = 1
            print(len(jsonline))
            for i in range(len(jsonline)):

                if tmpCount >= len(jsonline):
                    jsonline.append(']')
                else:
                    jsonline[i]=jsonline[i].replace("\n",",\n")

                tmpCount+=1
        jsonline.insert(0,'[\n')
        print(jsonline[0])
        for lines in jsonline:
            cleanData.writelines(lines)

# %%
for i in file_list:
    filename = path+i
    filename_split = i.split('.')
    filename_new = save_path+filename_split[0]+'_clean.json'
    print(filename)
    if filename != 'D:\\福壽_產學資料\\製粒機\\0831\\.ipynb_checkoptions':
        if filename_split != 'D:\\福壽_產學資料\\製粒機_第一次處理\\0831\\_clean.json':
            cleanJsonData(filename,filename_new)
    print(filename)
# Out:
# D:\福壽_產學資料\製粒機\0901\2020090100.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090100.json
# D:\福壽_產學資料\製粒機\0901\2020090101.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090101.json
# D:\福壽_產學資料\製粒機\0901\2020090102.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090102.json
# D:\福壽_產學資料\製粒機\0901\2020090103.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090103.json
# D:\福壽_產學資料\製粒機\0901\2020090104.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090104.json
# D:\福壽_產學資料\製粒機\0901\2020090105.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090105.json
# D:\福壽_產學資料\製粒機\0901\2020090106.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090106.json
# D:\福壽_產學資料\製粒機\0901\2020090107.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090107.json
# D:\福壽_產學資料\製粒機\0901\2020090108.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090108.json
# D:\福壽_產學資料\製粒機\0901\2020090109.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090109.json
# D:\福壽_產學資料\製粒機\0901\2020090110.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090110.json
# D:\福壽_產學資料\製粒機\0901\2020090111.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090111.json
# D:\福壽_產學資料\製粒機\0901\2020090112.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090112.json
# D:\福壽_產學資料\製粒機\0901\2020090113.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090113.json
# D:\福壽_產學資料\製粒機\0901\2020090114.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090114.json
# D:\福壽_產學資料\製粒機\0901\2020090115.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090115.json
# D:\福壽_產學資料\製粒機\0901\2020090116.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090116.json
# D:\福壽_產學資料\製粒機\0901\2020090117.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090117.json
# D:\福壽_產學資料\製粒機\0901\2020090118.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090118.json
# D:\福壽_產學資料\製粒機\0901\2020090119.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090119.json
# D:\福壽_產學資料\製粒機\0901\2020090120.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090120.json
# D:\福壽_產學資料\製粒機\0901\2020090121.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090121.json
# D:\福壽_產學資料\製粒機\0901\2020090122.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090122.json
# D:\福壽_產學資料\製粒機\0901\2020090123.json
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# spacs line
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [
#
# D:\福壽_產學資料\製粒機\0901\2020090123.json
